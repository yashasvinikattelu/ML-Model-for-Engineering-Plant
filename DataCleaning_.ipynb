# %% [markdown]
# ## **1. Give Colab Access to your Google Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# ## **2: Import the required libraries: Pandas and Numpy**

# %%
import pandas as pd
import numpy as np
# If you need the profiler, uncomment the next line when running interactively
# !pip install ydata-profiling
from ydata_profiling import ProfileReport

# %% [markdown]
# ## **3. Open the Excel with Data**

# %%
df = pd.read_excel('/content/gdrive/MyDrive/predictive_maintenance_raw.xlsx', header=1)
df

# %% [markdown]
# ## **4. Remove any data that isn't appropriate**
# *   Any text in numeral columns
# *   Any rows with empty cells
# *   Any data that is not necessary
# *   Any duplicates

# %%
# Add your data cleaning steps below
# Example:
# df = df.dropna()
# df = df.drop_duplicates()
# df = df.apply(pd.to_numeric, errors='coerce')
pass
